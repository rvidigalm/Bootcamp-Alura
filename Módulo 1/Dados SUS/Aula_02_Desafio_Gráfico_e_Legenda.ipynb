# %% [markdown]
# #Explorando dados DataSUS a partir de 2008

# %% [markdown]
# ##Aquisição de Dados Reais
#
#
# *   Selecionar Produção Hospitalar;
# *   Link da cosnulta: [DataSUS](https://datasus.saude.gov.br/acesso-a-informacao/producao-hospitalar-sih-sus)
# *   Opção: Dados Consolidados AIH (RD), por local de internação, a partir de 2008;
# *   Selecinar: Brasil por Região e Unidade da Federação;
# *   Selecionar as opções: "Unidade da Federação / Ano/mês atendimento / Valor Total";
# *   Selecionar Todos os períodos disponíveis.

# %% [markdown]
# Após o processamento, copiar a planilha como .CSV

# %% [markdown]
# Caderno de colaboração dos dados do datasus 2007 para frente

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/rvidigalm/Bootcamp-Alura/main/M%C3%B3dulo%201/Dados%20SUS/Dataset%20SUS%20Jan%202008%20-%202021%20-%20Atendimentos.csv"
dados = pd.read_csv(url, encoding="ISO-8859-1", sep=";", skiprows=3, skipfooter=12, thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
usaveis=usaveis.set_index("Unidade da Federação")
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996411254.68
# 12 Acre               10470.07  14001.71  ...  1137341.65  450048530.47
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917247936.05
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876965.09
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705309002.29
#
# [5 rows x 165 columns]

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis['2018/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    9124967.84
# 12 Acre        3040645.05
# 13 Amazonas   16374961.41
# 14 Roraima     3328230.63
# 15 Pará       35618364.04
# Name: 2018/Ago, dtype: float64

# %%
pd.options.display.float_format="{:.2f}".format
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
usaveis = usaveis.drop("Total", axis=1)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = usaveis.T.plot(figsize=(10,6))

plt.show()

# %% [markdown]
# ##Desafio 01 ##
#   #### Reposicionar a legenda. Dentro? Fora? Onde?

# %%
ax = usaveis.T.plot(figsize=(10,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()

# %% [markdown]
# ## Desafio 02
#   #### Selecionar 05 Estados para plotar no gráfico.

# %%
usaveis_t=usaveis.T
usaveis_t.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
def grafico(uf1, uf2, uf3, uf4, uf5 ):
  dados_df = usaveis_t[[uf1, uf2, uf3, uf4, uf5]]  
  ax = dados_df.plot(figsize=(10,6))
  ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
  ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.xlabel("Ano/Mês")
  plt.ylabel("Valor Total de Atendimento")
  plt.title("Valor Total de Atendimento no SUS por Ano/Mês \n e por unidade da Federação")
  plt.show()

# %%
grafico('12 Acre','15 Pará', '29 Bahia', '16 Amapá', '52 Goiás')
